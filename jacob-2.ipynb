# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("full_data.csv")
df
# Out:
#      id conducted_by recruitment_source         group  \
# 0     1        Jacob              other       control
# 1     5        Jacob              other       control
# 2     7        Jacob              other       control
# 3     9        Jacob              other       control
# 4    11        Jacob              other       control
# ..  ...          ...                ...           ...
# 93  127        Jacob               xlab  highlighting
# 94  128        Jacob              other  highlighting
# 95  129        Jacob               xlab  highlighting
# 96  130        Jacob              other  highlighting
# 97  131        Jacob              other  highlighting
#
#                                               q1               q2  \
# 0               ["Apple", "Orange", "Pineapple"]  [0, 1, 2, 3, 4]
# 1               [“Apple”, “Orange”, “Pineapple”]  [0, 1, 2, 3, 4]
# 2               ["Apple", "Orange", "Pineapple"]  [0, 1, 2, 3, 4]
# ...

# %%
df.columns
# Out:
# Index(['id', 'conducted_by', 'recruitment_source', 'group', 'q1', 'q2', 'q3',
#        'library_exp', 'self_est_prog_exp', 'yrs_prog_weekly', 'yrs_prog',
#        'major_occupation', 'helpful_exp', 'feedback_improvement',
#        'feedback_other', 'recruitment_source_detail', 'beautiful_soup',
#        'numpy', 'pandas', 'matplotlib', 'pytorch', 'flask', 'nltk', 'time',
#        'interface', 'task1', 'task2', 'task3', 'taskStart1', 'taskStart2',
#        'taskStart3', 'taskEnd1', 'taskEnd2', 'taskEnd3', 'timesRan1',
#        'timesRan2', 'timesRan3', 'timesUsed1', 'timesUsed2', 'timesUsed3',
#        'taskCompletion1', 'taskCompletion2', 'taskCompletion3', 'taskAnswer1',
#        'taskAnswer2', 'taskAnswer3', 'delete', 'taskTime1', 'taskTime2',
#        'taskTime3', 'correct1', 'correct2', 'correct3'],
#       dtype='object')

# %%
library_exp_counts = df.groupby("group")[["beautiful_soup", "flask", "matplotlib", "nltk",  "numpy", "pandas", "pytorch"]].sum()
library_exp_counts
# Out:
#                   beautiful_soup  flask  matplotlib  nltk  numpy  pandas  \
# group
# canonicalization               3      5           9     1     12      11
# control                        3      0          12     2     14      11
# highlighting                   4      3           8     2     14      10
# llmbasic                       3      3          10     0     12      10
# llmtranslation                 2      3           9     0     11      10
# sequence                       4      2          11     0     11      12
# translation                    3      0           9     0     13      10
#
#                   pytorch
# group
# canonicalization        3
# control                 1
# highlighting            4
# llmbasic                2
# llmtranslation          2
# sequence                3
# translation             3

# %%
def df_to_latex(df):
    sep = ""
    for feat in df.columns:
        print(r" & \texttt{" + feat.replace("_", r"\_") + "}", end = "")
    print(r" \\")
    for n, row in df.iterrows():
        print(n, end="")
        for col in row:
            print(" &", col, end = "")
        print(r" \\")

df_to_latex(library_exp_counts)
# Out:
#  & \texttt{beautiful\_soup} & \texttt{flask} & \texttt{matplotlib} & \texttt{nltk} & \texttt{numpy} & \texttt{pandas} & \texttt{pytorch} \\
# canonicalization & 3 & 5 & 9 & 1 & 12 & 11 & 3 \\
# control & 3 & 0 & 12 & 2 & 14 & 11 & 1 \\
# highlighting & 4 & 3 & 8 & 2 & 14 & 10 & 4 \\
# llmbasic & 3 & 3 & 10 & 0 & 12 & 10 & 2 \\
# llmtranslation & 2 & 3 & 9 & 0 & 11 & 10 & 2 \\
# sequence & 4 & 2 & 11 & 0 & 11 & 12 & 3 \\
# translation & 3 & 0 & 9 & 0 & 13 & 10 & 3 \\

# %%
sns.heatmap(library_exp_counts)
# Out:
# <Axes: ylabel='group'>

# %%
df.groupby("numpy")[["taskTime1", "taskTime2", "taskTime3"]].mean()
# Out:
#            taskTime1      taskTime2      taskTime3
# numpy
# False  684735.363636  859081.545455  556878.909091
# True   914772.735632  799695.413793  458220.275862

# %%
df.groupby("pandas")[["taskTime1", "taskTime2", "taskTime3"]].mean()
# Out:
#             taskTime1      taskTime2      taskTime3
# pandas
# False   903336.375000  832827.291667  540187.541667
# True    884287.081081  797777.608108  446301.770270

# %%
df.groupby("pytorch")[["taskTime1", "taskTime2", "taskTime3"]].mean()
# Out:
#              taskTime1      taskTime2      taskTime3
# pytorch
# False    899936.825000  856100.287500  447212.237500
# True     840131.722222  585298.611111  567436.277778

# %%
df.groupby("beautiful_soup")[["taskTime1", "taskTime2", "taskTime3"]].mean()
# Out:
#                     taskTime1      taskTime2      taskTime3
# beautiful_soup
# False           921443.921053  819320.276316  472519.250000
# True            776708.136364  761593.500000  458153.136364

# %%
df["self_est_prog_exp"].median()
# Out:
# 6.0

# %%
yrs_prog_numerical = df["yrs_prog"].replace(["<1 year ago", "Less than 1 year ago"], 0).replace("10 or more years ago", 10).astype(int)
yrs_prog_numerical.median()
# Out:
# 4.0

# %%
yrs_prog_weekly_numerical = df["yrs_prog_weekly"].replace(["<1 year", "Less than 1 year"], 0).replace("10 or more years", 10).astype(int)
yrs_prog_weekly_numerical.median()
# Out:
# 3.0

# %%
demog_numerical = df[["group", "self_est_prog_exp"]].copy().rename(columns={"self_est_prog_exp" : "self-estimated programming experience"})
demog_numerical["years programming experience"] = yrs_prog_numerical
demog_numerical["years programming on a weekly basis"] = yrs_prog_weekly_numerical
demog_numerical
# Out:
#            group  self-estimated programming experience  \
# 0        control                                      6
# 1        control                                      6
# 2        control                                      6
# 3        control                                      4
# 4        control                                      6
# ..           ...                                    ...
# 93  highlighting                                      5
# 94  highlighting                                      7
# 95  highlighting                                      7
# 96  highlighting                                      5
# 97  highlighting                                      8
#
#     years programming experience  years programming on a weekly basis
# 0                              5                                    2
# 1                              5                                    3
# 2                              3                                    2
# ...

# %%
demog_by_group = demog_numerical.groupby("group").median()
df_to_latex(demog_by_group)
# Out:
#  & \texttt{self-estimated programming experience} & \texttt{years programming experience} & \texttt{years programming on a weekly basis} \\
# canonicalization & 7.0 & 4.0 & 3.0 \\
# control & 6.0 & 4.0 & 2.5 \\
# highlighting & 6.0 & 5.5 & 2.0 \\
# llmbasic & 6.0 & 4.0 & 2.0 \\
# llmtranslation & 5.0 & 5.0 & 2.0 \\
# sequence & 6.5 & 4.5 & 4.0 \\
# translation & 7.0 & 3.5 & 2.5 \\

# %%
df_to_latex(demog_by_group.iloc[:, :1])
# Out:
#  & \texttt{self-estimated programming experience} \\
# canonicalization & 7.0 \\
# control & 6.0 \\
# highlighting & 6.0 \\
# llmbasic & 6.0 \\
# llmtranslation & 5.0 \\
# sequence & 6.5 \\
# translation & 7.0 \\

# %%
df_to_latex(demog_by_group.iloc[:, 1:2])
# Out:
#  & \texttt{years programming experience} \\
# canonicalization & 4.0 \\
# control & 4.0 \\
# highlighting & 5.5 \\
# llmbasic & 4.0 \\
# llmtranslation & 5.0 \\
# sequence & 4.5 \\
# translation & 3.5 \\

# %%
df_to_latex(demog_by_group.iloc[:, 2:3])
# Out:
#  & \texttt{years programming on a weekly basis} \\
# canonicalization & 3.0 \\
# control & 2.5 \\
# highlighting & 2.0 \\
# llmbasic & 2.0 \\
# llmtranslation & 2.0 \\
# sequence & 4.0 \\
# translation & 2.5 \\

# %%
timesByTask = df.melt(id_vars = ["group", "self_est_prog_exp", "yrs_prog", "yrs_prog_weekly", 'beautiful_soup',
       'numpy', 'pandas', 'matplotlib', 'pytorch', 'flask', 'nltk'], value_vars=["taskTime1", "taskTime2", "taskTime3"])
timesByTask
# Out:
#             group  self_est_prog_exp              yrs_prog   yrs_prog_weekly  \
# 0         control                  6                     5                 2
# 1         control                  6                     5                 3
# 2         control                  6                     3                 2
# 3         control                  4                     2                 2
# 4         control                  6                     2                 1
# ..            ...                ...                   ...               ...
# 289  highlighting                  5                     5                 2
# 290  highlighting                  7                     7                 4
# 291  highlighting                  7                     5                 4
# 292  highlighting                  5                     9                 2
# 293  highlighting                  8  10 or more years ago  10 or more years
#
# ...

# %%
correctnessByTask = df.melt(id_vars = ["group", "self_est_prog_exp", "yrs_prog", "yrs_prog_weekly", 'beautiful_soup',
       'numpy', 'pandas', 'matplotlib', 'pytorch', 'flask', 'nltk'], value_vars=["correct1", "correct2", "correct3"])
correctnessByTask
# Out:
#             group  self_est_prog_exp              yrs_prog   yrs_prog_weekly  \
# 0         control                  6                     5                 2
# 1         control                  6                     5                 3
# 2         control                  6                     3                 2
# 3         control                  4                     2                 2
# 4         control                  6                     2                 1
# ..            ...                ...                   ...               ...
# 289  highlighting                  5                     5                 2
# 290  highlighting                  7                     7                 4
# 291  highlighting                  7                     5                 4
# 292  highlighting                  5                     9                 2
# 293  highlighting                  8  10 or more years ago  10 or more years
#
# ...

# %%
timesByTask["correct"] = correctnessByTask["value"]
timesByTaskCorrect = timesByTask[timesByTask["correct"] == True]
timesByTaskCorrect
# Out:
#             group  self_est_prog_exp              yrs_prog   yrs_prog_weekly  \
# 0         control                  6                     5                 2
# 1         control                  6                     5                 3
# 2         control                  6                     3                 2
# 3         control                  4                     2                 2
# 4         control                  6                     2                 1
# ..            ...                ...                   ...               ...
# 289  highlighting                  5                     5                 2
# 290  highlighting                  7                     7                 4
# 291  highlighting                  7                     5                 4
# 292  highlighting                  5                     9                 2
# 293  highlighting                  8  10 or more years ago  10 or more years
#
# ...

# %%
sns.barplot(timesByTaskCorrect, x="variable", y="value", hue="pytorch", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect, x="variable", y="value", hue="numpy", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect, x="variable", y="value", hue="matplotlib", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect, x="variable", y="value", hue="beautiful_soup", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(correctnessByTask, x="variable", y="value", hue="pytorch")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(correctnessByTask, x="variable", y="value", hue="numpy")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(correctnessByTask, x="variable", y="value", hue="matplotlib")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(correctnessByTask, x="variable", y="value", hue="beautiful_soup")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect, x="variable", y="value", hue="group", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect[timesByTaskCorrect["pytorch"] == True], x="variable", y="value", hue="group", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect[timesByTaskCorrect["numpy"] == True], x="variable", y="value", hue="group", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
sns.barplot(timesByTaskCorrect[timesByTaskCorrect["beautiful_soup"] == True], x="variable", y="value", hue="group", estimator="median")
# Out:
# <Axes: xlabel='variable', ylabel='value'>
